# %%
import pandas as pd

# %%
df = pd.read_csv('Sample - Superstore.csv', index_col=False, encoding='cp1251')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
import matplotlib

# %matplotlib inline

# %%
df.Segment.value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
import datetime
import time

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%m/%d/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['ShipYearMonth'] = df['Ship Date'].dt.year * 100 + df['Ship Date'].dt.month

# %%
df_profit_by_month = df[['ShipYearMonth', 'Profit']].groupby(by=['ShipYearMonth']).sum().reset_index()

# %%
df_profit_by_month
# Out:
#     ShipYearMonth      Profit
# 0          201401   2424.1125
# 1          201402    866.1925
# 2          201403    123.4122
# 3          201404   3313.2568
# 4          201405   2636.2171
# 5          201406   5316.8660
# 6          201407  -1047.8993
# 7          201408   6161.5346
# 8          201409   6835.8856
# 9          201410   4567.7754
# 10         201411   9415.3468
# 11         201412   6680.0253
# 12         201501  -1455.5695
# 13         201502   3158.6857
# 14         201503   9762.9141
# 15         201504   1558.4000
# 16         201505   5562.9605
# 17         201506   5222.5484
# 18         201507   2940.2336
# 19         201508   3650.4602
# 20         201509   8713.5774
# 21         201510   3601.8000
# 22         201511  12362.3376
# 23         201512   7803.1819
# 24         201601   3445.7653
# 25         201602   5274.3035
# 26         201603   3718.0314
# 27         201604   2831.8084
# 28         201605   6356.6381
# 29         201606   6663.7107
# ...

# %%
import matplotlib.pyplot as plt

# %%
#avg_text = "Average refresh time = " + '{:.2f}'.format(avg_time)
title_text = "Profit by Month and Year"
#fig.set_title( title_text  )

base_y = 11
base_x = 2.2 * base_y


plt.figure(figsize=(base_x, base_y))

plt.title(title_text, {'fontsize':24 } )

#plt.line(df_h["Date"], df_h["AvgDuration"])
#plt.figure(figsize=(10,200))


colors = ["royalblue"]

plt.bar(df_profit_by_month['ShipYearMonth'], df_profit_by_month['Profit'], color = colors )


for x,y in zip( df_profit_by_month['ShipYearMonth'], df_profit_by_month['Profit']):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center',  # horizontal alignment can be left, right or center
                fontsize=15   # font size
                )

plt.show()

# %%
plt.plot(df_profit_by_month['ShipYearMonth'], df_profit_by_month['Profit'])
base_y = 40
base_x = 30 * base_y
plt.figure(figsize=(base_x, base_y))
plt.show()

# %%
df_profit_by_month = df[['ShipYearMonth', 'Profit']].groupby(by=['ShipYearMonth']).sum().reset_index()

# %%
df2016 = df[df['Ship Date'].dt.year==2016][['ShipYearMonth', 'Profit']].groupby(by=['ShipYearMonth']).sum().reset_index()

# %%
df2016
# Out:
#     ShipYearMonth      Profit
# 0          201601   3445.7653
# 1          201602   5274.3035
# 2          201603   3718.0314
# 3          201604   2831.8084
# 4          201605   6356.6381
# 5          201606   6663.7107
# 6          201607   4801.1517
# 7          201608   2076.1467
# 8          201609   9359.3231
# 9          201610  15629.3249
# 10         201611  11669.3287
# 11         201612  11115.5692

# %%
#avg_text = "Average refresh time = " + '{:.2f}'.format(avg_time)
title_text = "Profit by Month in 2016"
#fig.set_title( title_text  )

base_y = 11
base_x = 2.5 * base_y


plt.figure(figsize=(base_x, base_y))

plt.title(title_text, {'fontsize':24 } )

#plt.line(df_h["Date"], df_h["AvgDuration"])
#plt.figure(figsize=(10,200))


colors = ["royalblue"]

plt.bar(df2016['ShipYearMonth'], df2016['Profit'], color = colors )


for x,y in zip( df2016['ShipYearMonth'], df2016['Profit']):

    label = "{:,.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center',  # horizontal alignment can be left, right or center
                fontsize=15   # font size
                )

plt.show()
